# %%
import math
import numpy as np


from math import sqrt, pi
print(sqrt(4))


print(np.pi)

print(9//2)
# Out:
# 2.0
# 3.141592653589793
# 4

# %%
from package.maths import addition, difference
from package.mult.multiply  import multiplication

print(addition(1,2))
print(difference(1,2))
print(multiplication(1,2))
# Out:
# 3
# -1
# 2
